# %%
'''This script demonstrates simulations of coin flipping'''
import random
import numpy as np

# let's create a fair coin object that can be flipped:

class Coin(object):
    '''this is a simple fair coin, can be pseudorandomly flipped'''
    last_result = None

    def flip(self):
        '''call coin.flip() to flip the coin and record it as the last result'''
        self.last_result = result = random.normalvariate(30, 7.564)
        return result

# let's create some auxilliary functions to manipulate the coins:

def create_coins(number):
    '''create a list of a number of coin objects'''
    return [Coin() for _ in xrange(number)]

def flip_coins(coins):
    '''side effect function, modifies object in place, returns None'''
    for coin in coins:
        coin.flip()

def count_min(flipped_coins):
    return min(coin.last_result for coin in flipped_coins)

def count_max(flipped_coins):
    return max(coin.last_result for coin in flipped_coins)

def main():
    coins = create_coins(1000)
    for i in xrange(100):
        flip_coins(coins)
        print(count_min(coins)),(count_max(coins))

if __name__ == '__main__':
    main()
# Out:
# 9.39488665693 62.1207030947
# 5.98091152265 54.6988376145
# 1.71118024864 55.7709341927
# 10.0285307198 51.944726438
# 5.69233913933 53.9543626966
# 1.96551705878 50.2978379228
# 11.1359602163 59.2022737413
# 6.95430497384 52.4487600685
# 6.32104296101 53.8984426899
# 4.17575593839 57.8317014883
# 2.17906731057 51.8790182974
# 7.28496946568 51.3327208567
# 6.96125919155 50.2903462492
# 8.46347569821 52.5785969074
# 2.28271806639 56.2170283987
# 7.96458035637 51.2511107775
# 4.38732490054 52.7229208157
# 8.27927380418 56.0037018575
# 8.45687221626 53.8517563362
# 5.62358089027 57.976303172
# 2.7800375379 52.872997419
# 10.1098087921 56.1950747443
# 5.81382251865 57.2568204622
# 8.07915467004 50.1223746293
# 8.28953961686 51.5424043197
# 3.91691400944 51.6738699036
# 2.56827643396 51.7267309256
# 7.70797283273 51.2333258995
# 4.69944731127 52.0649945882
# 9.09001577636 55.8495743997
# 3.48022122861 50.5413234717
# 2.67921454169 54.927713376
# 5.6599798379 58.6047861972
# 7.58248579572 56.9002811231
# 0.646154292662 54.1680951583
# 6.82315556626 51.6341858303
# 4.10083173283 52.0714610007
# 1.83498187865 52.9256663815
# 5.54143825943 56.6338357731
# 3.88857771273 53.1269241586
# 6.92162095898 50.0268519867
# 4.68083477706 57.3102911904
# 4.423125128 52.3679132469
# 5.33697961498 52.7948436358
# 7.67171980604 54.9788274386
# 4.40139068213 55.4638477115
# 5.33015896741 53.1845201543
# 7.7192026178 57.7549432468
# 7.13712351183 56.2654001838
# 4.31673962167 50.6897373721
# 6.45383560511 54.9501883429
# 4.96721520815 55.179260066
# 6.72649993652 52.4675716227
# 4.02858448775 53.8588508634
# 7.11378224751 59.4027893911
# 4.84532893953 54.1916495678
# 6.4653706138 50.9507178528
# 3.68298333368 58.02677687
# 5.43701099167 57.0265125947
# 4.90126864449 52.5525644866
# 8.02767692981 59.0961674948
# 6.39105718128 54.5167306662
# 7.50789089549 53.4030395087
# 1.20574746582 53.6626052975
# 4.33302045693 51.7679948345
# 5.49661594328 64.3629385702
# 5.77079964471 50.013938357
# 2.39913293027 56.0184853389
# 6.29605240263 52.1725761221
# 6.83330473447 59.9169708736
# 4.34048993153 53.7487131119
# 7.32725696423 59.2150553175
# 4.36438390109 54.9789747981
# 10.191301327 51.1029753614
# 6.57378787566 58.0995529655
# 7.15446449268 54.670030631
# 3.2981359889 51.2949864177
# -1.91450054567 54.6668329513
# 6.43958914353 54.7063294571
# 2.03725728363 50.7609193694
# 7.33008760026 51.915678374
# 7.23378687142 57.0029616441
# 3.03473957932 55.5096527568
# 6.19487661105 56.8379669161
# 1.56098354175 53.3784320472
# 8.19524515364 52.699745006
# 1.95802691607 54.2349815169
# 2.39930711986 54.1593553738
# 5.63436743743 53.0230095913
# 1.94154432607 58.8660377906
# 7.31866552376 53.5705714528
# 8.94040217509 52.7438433093
# 7.4393149713 52.089491207
# 4.24836558191 53.6114725156
# 5.37372593935 57.4872041198
# 8.57879950967 52.2411325376
# 8.9334800733 54.9872111388
# 6.63007626826 53.0263750169
# 6.26103141699 50.3005469398
# 8.12690775288 53.2714383125
